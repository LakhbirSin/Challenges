# %%
# importation du librairie
import pandas as pd

# %%
# création dataframe et import fichier
df_google_ap_1= pd.read_csv("googleplaystore_1.csv" ,sep =";")

# %%
df_google_ap_1
# Out:
#                                                    App        Category Rating  \
# 0       Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN    4.1
# 1                                  Coloring book moana  ART_AND_DESIGN    3.9
# 2                                Sketch - Draw & Paint  ART_AND_DESIGN    4.5
# 3                Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN    4.3
# 4                           Paper flowers instructions  ART_AND_DESIGN    4.4
# ..                                                 ...             ...    ...
# 495                          BBWCupid - BBW Dating App          DATING    3.5
# 496                          ChatVideo Meet new people          DATING    4.2
# 497  Black White Interracial Dating - Interracial M...          DATING    4.1
# 498             FlirtChat - ♥Free Dating/Flirting App♥          DATING    4.3
# 499                                     OkCupid Dating          DATING    4.1
#
# ...

# %%
#selections colonnes
df_google_ap_1[["Category","Genres","App","Installs"]]
# Out:
#            Category        Genres  \
# 0    ART_AND_DESIGN  Art & Design
# 1    ART_AND_DESIGN  Art & Design
# 2    ART_AND_DESIGN  Art & Design
# 3    ART_AND_DESIGN  Art & Design
# 4    ART_AND_DESIGN  Art & Design
# ..              ...           ...
# 495          DATING        Dating
# 496          DATING        Dating
# 497          DATING        Dating
# 498          DATING        Dating
# 499          DATING        Dating
#
#                                                    App     Installs
# 0       Photo Editor & Candy Camera & Grid & ScrapBook      10,000+
# 1                                  Coloring book moana     500,000+
# 2                                Sketch - Draw & Paint  50,000,000+
# 3                Pixel Draw - Number Art Coloring Book     100,000+
# 4                           Paper flowers instructions      50,000+
# ..                                                 ...          ...
# 495                          BBWCupid - BBW Dating App      50,000+
# ...

# %%
df_google_ap_1[["Installs"]]
# Out:
#         Installs
# 0        10,000+
# 1       500,000+
# 2    50,000,000+
# 3       100,000+
# 4        50,000+
# ..           ...
# 495      50,000+
# 496   5,000,000+
# 497     100,000+
# 498     500,000+
# 499  10,000,000+
#
# [500 rows x 1 columns]

# %%
type(df_google_ap_1["Installs"])
# Out:
# pandas.core.series.Series

# %%
#ordonnée
df_google_ap_1.sort_values(by = 'Price', ascending = True)
# Out:
#                                                App  \
# 449                              Truth or Dare Pro
# 450                           Ad Blocker for SayHi
# 401                             Puffin Browser Pro
# 218  TurboScan: scan documents and receipts in PDF
# 219                 Tiny Scanner Pro: PDF Doc Scan
# ..                                             ...
# 499                                 OkCupid Dating
# 57                       REG - Check the regnumber
# 422                          Truecaller: Caller ID
# 392                         Dolphin Browser - Fast
# 427                     myMail – Email for Hotmail
#
#                                      Category             Rating   Reviews  \
# 449                                    DATING                NaN       0.0
# 450                                    DATING                NaN       4.0
# 401                             COMMUNICATION                4.0   18247.0
# ...

# %%
df_google_ap_1.items()
# Out:
# <generator object DataFrame.items at 0x000001F4889C3AC0>

# %%
# prend toutes les app dont l'installation est supérieur à 1 Milliard.
filter1 = df_google_ap_1[df_google_ap_1["Installs"] == "1,000,000,000+"]
filter1
# Out:
#                                           App             Category Rating  \
# 139                         Google Play Books  BOOKS_AND_REFERENCE    3.9
# 313  Messenger – Text and Video Chat for Free        COMMUNICATION    4.0
# 314                        WhatsApp Messenger        COMMUNICATION    4.4
# 316              Google Chrome: Fast & Secure        COMMUNICATION    4.3
# 318                                     Gmail        COMMUNICATION    4.3
# 319                                  Hangouts        COMMUNICATION    4.0
# 359                        WhatsApp Messenger        COMMUNICATION    4.4
# 360  Messenger – Text and Video Chat for Free        COMMUNICATION    4.0
# 364                                  Hangouts        COMMUNICATION    4.0
# 368             Skype - free IM & video calls        COMMUNICATION    4.1
# 386              Google Chrome: Fast & Secure        COMMUNICATION    4.3
# 424                                     Gmail        COMMUNICATION    4.3
# ...

# %%
# app la plus chére
filter2 = df_google_ap_1[df_google_ap_1["Price"] == "$7.99"]
filter2
# Out:
#                                                    App Category Rating  \
# 451  AMBW Dating App: Asian Men Black Women Interra...   DATING    3.5
#
#      Reviews Size Installs  Type  Price Content Rating  Genres  \
# 451      2.0  17M     100+  Paid  $7.99     Mature 17+  Dating
#
#          Last Updated Current Ver Android Ver
# 451  January 21, 2017       1.0.1  4.0 and up

# %%
# App avec plus de avis
filter3 = df_google_ap_1[df_google_ap_1["Reviews"]==max(df_google_ap_1["Reviews"])]
filter3.iloc[0][['App',"Reviews",'Rating']]
# Out:
# App        WhatsApp Messenger
# Reviews            69119316.0
# Rating                    4.4
# Name: 314, dtype: object

# %%
# nombre d'app installable par tout le monde
filter4 = df_google_ap_1[df_google_ap_1["Content Rating"] == "Everyone"]
len(filter4)
# Out:
# 391

# %%
# nombre d'app installable par tout le monde apres avoir supprimer les doublons
db_filter4 = filter4.App.drop_duplicates()
len(db_filter4)
# Out:
# 326

# %%
# Catégorie la plus présente
df_google_ap_1["Category"].mode()
# Out:
# 0    COMMUNICATION
# Name: Category, dtype: object

# %%
df_google_ap_1.iloc[3:16,[2,5,6]]
# Out:
#    Rating     Installs  Type
# 3     4.3     100,000+  Free
# 4     4.4      50,000+  Free
# 5     3.8      50,000+  Free
# 6     4.1   1,000,000+  Free
# 7     4.4   1,000,000+  Free
# 8     4.7      10,000+  Free
# 9     4.4   1,000,000+  Free
# 10    4.4   1,000,000+  Free
# 11    4.2  10,000,000+  Free
# 12    4.6     100,000+  Free
# 13    4.4     100,000+  Free
# 14    3.2       5,000+  Free
# 15    4.7     500,000+  Free
